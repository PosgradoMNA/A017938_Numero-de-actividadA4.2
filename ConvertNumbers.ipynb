# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/A017938_Numero-de-actividadA4.2/blob/main/ConvertNumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pylint
# Out:
# Requirement already satisfied: pylint in /usr/local/lib/python3.10/dist-packages (3.0.3)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pylint) (4.2.0)
# Requirement already satisfied: astroid<=3.1.0-dev0,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from pylint) (3.0.3)
# Requirement already satisfied: isort!=5.13.0,<6,>=4.2.5 in /usr/local/lib/python3.10/dist-packages (from pylint) (5.13.2)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.10/dist-packages (from pylint) (0.7.0)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from pylint) (0.12.3)
# Requirement already satisfied: dill>=0.2 in /usr/local/lib/python3.10/dist-packages (from pylint) (0.3.8)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pylint) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from astroid<=3.1.0-dev0,>=3.0.1->pylint) (4.5.0)

# %%
import time
import sys

def convert_numbers(file_path):
    try:
        with open(file_path, 'r') as file:
            numbers = file.readlines()
    except FileNotFoundError:
        print(f"Error: El archivo {file_path} no fue encontrado.")
        return
    except Exception as e:
        print(f"Error al leer el archivo: {e}")
        return

    binary_results = []
    hex_results = []

    start_time = time.time()

    for num in numbers:
        try:
            num = int(num.strip())
            binary_results.append(bin(num)[2:])
            hex_results.append(hex(num)[2:])
        except ValueError:
            print(f"Error: '{num.strip()}' no es un número válido.")

    end_time = time.time()
    elapsed_time = end_time - start_time

    # Imprimir resultados en la pantalla
    print("Resultados en binario:")
    for result in binary_results:
        print(result)

    print("\nResultados en hexadecimal:")
    for result in hex_results:
        print(result)

    # Guardar resultados en el archivo
    with open("/content/sample_data/ConvertNumbersResults.txt", 'w') as result_file:
        result_file.write("Resultados en binario:\n")
        result_file.write('\n'.join(binary_results) + '\n\n')
        result_file.write("Resultados en hexadecimal:\n")
        result_file.write('\n'.join(hex_results) + '\n')

    # Imprimir tiempo transcurrido
    print(f"\nTiempo transcurrido: {elapsed_time:.4f} segundos")

# Cambia 'archivoWithData.txt' al nombre de tu archivo en Colab
file_path_in_colab = '/content/sample_data/ConvertNumbersResults.txt'
convert_numbers(file_path_in_colab)
# Out:
# Error: 'Resultados en binario:' no es un número válido.
# Error: '' no es un número válido.
# Error: 'Resultados en hexadecimal:' no es un número válido.
# Error: '6a8310' no es un número válido.
# Error: '542eff' no es un número válido.
# Error: '14635f' no es un número válido.
# Error: '66ffe9' no es un número válido.
# Error: '1b09a1' no es un número válido.
# Error: '581f8' no es un número válido.
# Error: '568e71' no es un número válido.
# Error: 'dfc67' no es un número válido.
# Error: '29336a' no es un número válido.
# Error: '932bfd' no es un número válido.
# Error: '1205b6' no es un número válido.
# Error: '16c4d9' no es un número válido.
# Error: '3d51a3' no es un número válido.
# Error: '74cde8' no es un número válido.
# Error: '6bc3b5' no es un número válido.
# Error: '25cfba' no es un número válido.
# Error: '5d9bf0' no es un número válido.
# Error: '807c41' no es un número válido.
# Error: '2c8471' no es un número válido.
# Error: '32f9e5' no es un número válido.
# Error: '8bf4e0' no es un número válido.
# Error: '5fb3fc' no es un número válido.
# Error: '848d5b' no es un número válido.
# Error: 'c72a' no es un número válido.
# Error: '8f129a' no es un número válido.
# Error: '5afa57' no es un número válido.
# Error: '754aeb' no es un número válido.
# Error: '64f08f' no es un número válido.
# Error: '1c748c' no es un número válido.
# Error: '32cfaa' no es un número válido.
# Error: '3c298a' no es un número válido.
# Error: '27e634' no es un número válido.
# Error: '7104b4' no es un número válido.
# Error: '24613e' no es un número válido.
# Error: '6140b' no es un número válido.
# Error: '84ba87' no es un número válido.
# Error: '91bf50' no es un número válido.
# Error: 'f8ea4' no es un número válido.
# Error: '35184d' no es un número válido.
# Error: '8e0b50' no es un número válido.
# Error: '505afa' no es un número válido.
# Error: '3e7984' no es un número válido.
# Error: '1ac3c7' no es un número válido.
# Error: '596f0c' no es un número válido.
# Error: '443a21' no es un número válido.
# Error: '86acc4' no es un número válido.
# Error: '71f90d' no es un número válido.
# Error: '1e1bb4' no es un número válido.
# Error: 'cf99' no es un número válido.
# Error: '3b78a4' no es un número válido.
# Error: '769cca' no es un número válido.
# Error: '5cec65' no es un número válido.
# Error: '4071c0' no es un número válido.
# Error: '94f3d8' no es un número válido.
# Error: '7903af' no es un número válido.
# Error: '36e4b7' no es un número válido.
# Error: '8df3a4' no es un número válido.
# Error: '22ec48' no es un número válido.
# Error: '505dfb' no es un número válido.
# Error: '796a23' no es un número válido.
# Error: '30c1e1' no es un número válido.
# Error: '6c6edd' no es un número válido.
# Error: '92fe20' no es un número válido.
# Error: '436c7e' no es un número válido.
# Error: '93bd4a' no es un número válido.
# Error: '276d10' no es un número válido.
# Error: '4bf9b6' no es un número válido.
# Error: '5fd6fa' no es un número válido.
# Error: '12bf42' no es un número válido.
# Error: 'ac3ee' no es un número válido.
# Error: 'f8735' no es un número válido.
# Error: '7a182' no es un número válido.
# Error: '6e06e7' no es un número válido.
# Error: '40dd12' no es un número válido.
# Error: '3ddff4' no es un número válido.
# Error: '2a06c0' no es un número válido.
# Error: '6e987' no es un número válido.
# Error: '683d62' no es un número válido.
# Error: '32b14' no es un número válido.
# Error: '6f17fb' no es un número válido.
# Error: '327d89' no es un número válido.
# Error: '41aad2' no es un número válido.
# Error: '7fcb0f' no es un número válido.
# Error: '163f28' no es un número válido.
# Error: '4f4f39' no es un número válido.
# Error: '2ffab3' no es un número válido.
# Error: '65d6da' no es un número válido.
# Error: '29140a' no es un número válido.
# Error: '22bda1' no es un número válido.
# Error: '1d9deb' no es un número válido.
# Error: '322cc8' no es un número válido.
# Error: '498b5b' no es un número válido.
# Error: '8fe7dd' no es un número válido.
# Error: '3ce9d3' no es un número válido.
# Error: '7ce3ce' no es un número válido.
# Error: '2b74e7' no es un número válido.
# Error: 'dbbf2' no es un número válido.
# Error: '1bf26c' no es un número válido.
# Error: '809add' no es un número válido.
# Error: '2c5698' no es un número válido.
# Error: '94f931' no es un número válido.
# Error: '3ef62' no es un número válido.
# Error: '47b671' no es un número válido.
# Error: '57c75' no es un número válido.
# Error: '40cd22' no es un número válido.
# Error: '1c3608' no es un número válido.
# Error: 'e51f0' no es un número válido.
# Error: '3bde20' no es un número válido.
# Error: '880af1' no es un número válido.
# Error: '41c066' no es un número válido.
# Error: '3b6033' no es un número válido.
# Error: '83a6f4' no es un número válido.
# Error: '59cac5' no es un número válido.
# Error: '1951b6' no es un número válido.
# Error: '1bff67' no es un número válido.
# Error: '33ad7f' no es un número válido.
# Error: '2dc766' no es un número válido.
# Error: '8b660a' no es un número válido.
# Error: '4a4c8c' no es un número válido.
# Error: '12b06' no es un número válido.
# Error: '6988f' no es un número válido.
# Error: '3d494' no es un número válido.
# Error: '6b0f1a' no es un número válido.
# Error: '6939e3' no es un número válido.
# Error: '7ff72e' no es un número válido.
# Error: '83cadb' no es un número válido.
# Error: 'e4b01' no es un número válido.
# Error: '64bdbf' no es un número válido.
# Error: '15cebd' no es un número válido.
# Error: '5d9449' no es un número válido.
# Error: '5a9715' no es un número válido.
# Error: '2bec72' no es un número válido.
# Error: '26ca5' no es un número válido.
# Error: '2542e5' no es un número válido.
# Error: '5a40aa' no es un número válido.
# Error: '3d0628' no es un número válido.
# Error: '2ff4f1' no es un número válido.
# Error: '7c6077' no es un número válido.
# Error: '4e8bac' no es un número válido.
# Error: '461eae' no es un número válido.
# Error: '409ec7' no es un número válido.
# Error: '783f9d' no es un número válido.
# Error: '6af681' no es un número válido.
# Error: 'a9d1c' no es un número válido.
# Error: '7076cb' no es un número válido.
# Error: '78e041' no es un número válido.
# Error: '6b2dd0' no es un número válido.
# Error: '3b99c4' no es un número válido.
# Error: '1af8af' no es un número válido.
# Error: 'e44e0' no es un número válido.
# Error: '9b38c' no es un número válido.
# Error: '4d7bf' no es un número válido.
# Error: '29a020' no es un número válido.
# Error: '7197af' no es un número válido.
# Error: '3e098b' no es un número válido.
# Error: '22ff81' no es un número válido.
# Error: '76062a' no es un número válido.
# Error: '1041f7' no es un número válido.
# Error: '10ded1' no es un número válido.
# Error: '5143e8' no es un número válido.
# Error: '3a53bf' no es un número válido.
# Error: '53fb72' no es un número válido.
# Error: '8c9867' no es un número válido.
# Error: '6383a9' no es un número válido.
# Error: '78e854' no es un número válido.
# Error: '501cbc' no es un número válido.
# Error: '7344d' no es un número válido.
# Error: '92720e' no es un número válido.
# Error: '18226f' no es un número válido.
# Error: 'a056f' no es un número válido.
# Error: '6414a3' no es un número válido.
# Error: '3acaba' no es un número válido.
# Error: '5f9193' no es un número válido.
# Error: '58eed4' no es un número válido.
# Error: '7af6a7' no es un número válido.
# Error: '89ddb7' no es un número válido.
# Error: '78e1b7' no es un número válido.
# Error: '8ee9f3' no es un número válido.
# 57b0f42cd71f2a7b9
# 3c3a5cc879ce6c4e2b
# 259c95674ecf3b6d048
# 254dbfc4f61df7eaf95
# 3643d1d3f789b37f22
# 2241e771711ba79a970
# 152d02c84658c6a3fe41
# 36ce7514ff08cf53f1
# 3ba2f843f5c6a898c5
# 56beae522686f3d14
# 152d8f19c32f7ac0b360
# 2241fda658b1dff65bc
# 152d10ac2596e5329a43
# 3e8744aded992
# 152d9cf6885705ef9b82
# 22411d682ef593b8bbf
# 259c9766e5ea04a5553
# 2545d8f20a711350ad7
# 6046f9cdc1c926ecc
# 3ba2f839f733285812
# 3c3a38eedb10740372
# 3645352270e6aabc14
# 259bb955ca2b8572894
# 3643aac884eae87306
# f43fd172d9ef7f3
# 152d10ac2f95ea6c78ef
# 15326eb65e046f521050
# 9a3233bb7c153384
# 5f6b596a31eac685e
# 3baf954a9976003e8d
# 152d9cd300930f6cfc50
# 22385a883db7f2a8c62
# 3c3b9c902f531d4fe4
# 5f7f5af1c41fb442f
# 224109336044bf95b4c
# 21e27c18a8700cee8a1
# 152d120f74278bd1c524
# 259bb994f2a8a763d4d
# 605d27e5e512ce794
# 3e88b93ecf879
# 3c2ddf606e1585f584
# 259cab9605b0f7438b2
# 2241e53f343e6e2f545
# 21e19e12eaeec6fa9c0
# 15327c73e89f1b851eb8
# 25a465c7fa52fc3cc77
# 3bb0d8f9ab9ef7889f
# 152d9b973468b2103884
# 363730e4e1dc6f7228
# 186cc6b08f50c4b
# 22385a883dd9d918763
# 1873076323e8dc9
# 25a465ce3c7d09918ab
# 3ba194f464fd900061
# 254e852b55df9de7a1d
# 15326ff6777d67918ca0
# 15327c7000446c842288
# 23eb00644a9675
# 21e1b67fa4a7b0ba046
# 15327019a37c91412332
# 364531950954b4b410
# 21ea632abb430d27d9e
# 2241fdab7682e1d0862
# 56d2e3b3f669ae94a
# 8c2e50eedeecceb6
# 9a3233a438fbbd15
# f6b19b56e76978a
# 254e9b596b3b0060dcf
# 21e19e4b32ede9ea41a
# 3c3a6056124b5fcdd4
# 36c1f41645566086c0
# f47edcd57a6bfef
# 254da71a49fe06925ea
# 186d59aa5c55a74
# 254e9d91e8efa622963
# 3ba2f4b67975dd3769
# 21e1a07e75b99f3d1da
# 25a55a4645a31cf5757
# 57b0b6474692ab188
# 21eb40fcaea9f666899
# 36cffc46733a3b663b
# 2545db29e83c23981c2
# 36c0b458a800f9f7f2
# 3637308ad7a71afa21
# 604964d5920aaa053
# 3ba2f45a9d8ad748a8
# 21ea4cf0147dac68043
# 152d9cfa78fa8f0ef31d
# 3c3a3cd74cc5c428db
# 25a541da0f06b27e816
# 36c218022bbe1a33cf
# 25a46395cd5254b3151
# 98cef841f39c497a
# 5f819400fce47072c
# 152d02cb6fc9f4a5461d
# 36ce71e35c854abf78
# 15327c73e8b627bae6b1
# 18abe0eaf229fea
# 21e294be45b7e84cdf1
# e04a2b3e74aac55
# 3baf755110bd19ebee
# 21e19e4b24609faf3aa
# 6046f41e9471a61e8
# 9a0b7b0c7a94b770
# 187317649ec7269
# 3c2de2e4d6fae7eca0
# 152d8d8f046705233871
# 21e1a08391ed752894e
# 3c2ddf5f6df7d18dbb
# 152d0452444f475454d4
# 2241096ba6848f34b25
# 5f6b264004868759e
# 5f819402970bfb04f
# 3ba31b6f0ea4bdc147
# 36ce98f6e4ca9b184e
# 152d8f1634c83c4691f2
# 21ea60b8d444747a6cc
# 239022483b336e
# f478aaac76912d7
# 18ab5c7abd571f4
# 254dbf86709c626a202
# 254da952b8ffcb6d86b
# 25a55a46e46607d89f6
# 152d0452963efdc575c3
# 9a0b7a3b2957d301
# 2545d8ec5cda3352587
# 579cf845f082d9e7d
# 152d02c7e24b1a2a6f8a
# 2241e7716fc83e3ba29
# 22411d61ecf0bca4675
# 36c21b8ed8d61a1bfa
# 163a99d5993c985
# 3643ce465f428369c5
# 22411d2eb580dd66112
# 3c3a5c6ca072653888
# 36cffc465e0a44da71
# 25a541a13718439d05f
# 21eb3ef7681707e346c
# 21e2924c6e9648ac776
# 21e19e4583c0470ff2f
# 25a463902cd7f9be8dd
# 254dbd8d272e0e9b481
# 8c2df6fe0356685c
# 259bb723aa4b7d07ab3
# 25a463cea3c819aa241
# 152d02c8465678804389
# 254dbf87021d9a64cd0
# 3c2de289e161633224
# 5f7f5b9346beb7977
# 9a0b7a25f4058360
# 8aee417703b075cc
# 152d120c4184b45e2c0f
# de4a010c780a787
# 1532f9566c8096474dfa
# 36c0b7ee53cb83a6a0
# 259bb98eb0a73534077
# 3c3b9c2b3b1f8b6373
# 15327df7278d55ec4138
# 363730e5caf32e7d81
# 259cab5d1dc88863892
# 56bc7b9207a29a7df
# 56bcb47a1c5bb65d1
# 22385cc09cdd7c54e48
# 3c2dbbd04c506c4387
# 2238732e6dd450bf2fa
# 152d9b734981e9bf414f
# 2545134d16a451c4c09
# 25a463cea53ca11b1b4
# 22385a828ea8712247c
# 56bcaebae9d73361a
# f678d21ebe1da8d
# 15326ff2e9e52646be56
# 5f68e8a4a77163737
# 8c2a687f41849237
# e04989b81b1f8d8
# 21e1a04ac894949918a
# 2545d8b2f1f618f112b
# 3c2dbf5cf9630eba22
# 2241fda5c7293e12e9b
# 22410733c907bb0f634
# 25a47a030a043fb3b8f
# 152d8db674b61d21c19f
# 25a463cea3c881b859f
# 152d9cd6f21cd81faf7b
# 21e27e894dfb0640425
# 3baf9932f3e2cb98e1
# 3ba19170fec3bf8637
# 98cb61aac42e1f28
# 36372d4f3169d1014e
# 1b08e
# 30cc4
# 7623
# 8d49
# e66d4
# 414b
# c01a3
# 55592
# 9401
# c3cbe
# c53f9
# d38df
# f0278
# eea32
# 1a8a8
# d532
# 65696
# 3724a
#
# Tiempo transcurrido: 0.0314 segundos
